# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import os
import random
from PIL import Image
from torchvision import transforms

# Define a folder to save augmented images
output_folder = 'augmented_images'
os.makedirs(output_folder, exist_ok=True)

# Define augmentations to be applied
augmentation_transform = transforms.Compose([
    transforms.RandomHorizontalFlip(p=0.5),           # Random horizontal flip
    transforms.RandomRotation(degrees=30),            # Random rotation
    transforms.RandomResizedCrop(size=(128, 128), scale=(0.8, 1.0)),  # Random crop and resize
    transforms.ColorJitter(brightness=0.4, contrast=0.4, saturation=0.4),  # Color jitter
    transforms.RandomAffine(degrees=30, translate=(0.1, 0.1), scale=(0.8, 1.2), shear=10),  # Random affine
])

# Load the original image (replace with your image path)
image_path = '/kaggle/input/catdata/catt.jpeg'  # Replace this path with your image
image = Image.open(image_path)

# Generate and save 20 augmented images
for i in range(20):
    # Apply the augmentation transform
    augmented_image = augmentation_transform(image)
    
    # Convert the augmented image to a PIL image and save it
    save_path = os.path.join(output_folder, f'augmented_image_{i+1}.jpg')
    augmented_image.save(save_path)
    
    print(f'Augmented image {i+1} saved to {save_path}')
# Out:
# Augmented image 1 saved to augmented_images/augmented_image_1.jpg
# Augmented image 2 saved to augmented_images/augmented_image_2.jpg
# Augmented image 3 saved to augmented_images/augmented_image_3.jpg
# Augmented image 4 saved to augmented_images/augmented_image_4.jpg
# Augmented image 5 saved to augmented_images/augmented_image_5.jpg
# Augmented image 6 saved to augmented_images/augmented_image_6.jpg
# Augmented image 7 saved to augmented_images/augmented_image_7.jpg
# Augmented image 8 saved to augmented_images/augmented_image_8.jpg
# Augmented image 9 saved to augmented_images/augmented_image_9.jpg
# Augmented image 10 saved to augmented_images/augmented_image_10.jpg
# Augmented image 11 saved to augmented_images/augmented_image_11.jpg
# Augmented image 12 saved to augmented_images/augmented_image_12.jpg
# Augmented image 13 saved to augmented_images/augmented_image_13.jpg
# Augmented image 14 saved to augmented_images/augmented_image_14.jpg
# ...

# %%
import matplotlib.pyplot as plt
import os
from PIL import Image

# Display a few of the augmented images
for i in range(1, 6):  # Display first 5 images
    img_path = f'augmented_images/augmented_image_{i}.jpg'
    img = Image.open(img_path)
    plt.imshow(img)
    plt.title(f'Augmented Image {i}')
    plt.axis('off')  # Hide axis
    plt.show()
