# %%
import pandas as pd

# %% [markdown]
# # Working with JSON

# %%
pd.read_json('train.json')
# Out:
#           id      cuisine                                        ingredients
# 0      10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1      25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2      20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3      22213       indian                [water, vegetable oil, wheat, salt]
# 4      13162       indian  [black pepper, shallots, cornflour, cayenne pe...
# ...      ...          ...                                                ...
# 39769  29109        irish  [light brown sugar, granulated sugar, butter, ...
# 39770  11462      italian  [KRAFT Zesty Italian Dressing, purple onion, b...
# 39771   2238        irish  [eggs, citrus fruit, raisins, sourdough starte...
# 39772  41882      chinese  [boneless chicken skinless thigh, minced garli...
# 39773   2362      mexican  [green chile, jalapeno chilies, onions, ground...
#
# [39774 rows x 3 columns]

# %% [markdown]
# # Working with SQL

# %%
# !pip install mysql.connector
# Out:
# Requirement already satisfied: mysql.connector in c:\users\absol\anaconda3\lib\site-packages (2.2.9)

# %%
import mysql.connector

# %%
import mysql.connector

try:
    connection = mysql.connector.connect(
        host='localhost',
        user='root',
        password='',  # Leave the password field empty
        database='world'
    )
    if connection.is_connected():
        print("Connected to the database")
except mysql.connector.Error as err:
    print(f"Error: {err}")
finally:
    if 'connection' in locals() and connection.is_connected():
        connection.close()
        print("Connection closed")
# Out:
# Error: 1045 (28000): Access denied for user 'root'@'localhost' (using password: NO)

# %%
pd.read_sql_query("SELECT * FROM city",connection)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 pd.read_sql_query("SELECT * FROM city",connection)
#
# NameError: name 'connection' is not defined

# %%
import pandas as pd
import requests

# %%
response = requests.get('https://api.themoviedb.org/3/tv/top_rated?api_key=06bdd5e2431dde0a36b52e5f389bc729')

# %%
response.json()
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/96RT2A47UdzWlUfvIERFyBsLhL2.jpg',
#    'genre_ids': [16, 18, 10759, 10765],
#    'id': 209867,
#    'origin_country': ['JP'],
#    'original_language': 'ja',
#    'original_name': '葬送のフリーレン',
#    'overview': 'After the party of heroes defeated the Demon King, they restored peace to the land and returned to lives of solitude. Generations pass, and the elven mage Frieren comes face to face with humanity’s mortality. She takes on a new apprentice and promises to fulfill old friends’ dying wishes. Can an elven mind make peace with the nature of life and death? Frieren embarks on her quest to find out.',
#    'popularity': 449.62,
#    'poster_path': '/dqZENchTd7lp5zht7BdlqM7RBhD.jpg',
#    'first_air_date': '2023-09-29',
#    'name': "Frieren: Beyond Journey's End",
#    'vote_average': 8.965,
#    'vote_count': 229},
#   {'adult': False,
#    'backdrop_path': '/9kyyQXy79YRdY5mhrYKyktbFMev.jpg',
#    'genre_ids': [16, 35, 10765],
#    'id': 94954,
#    'origin_country': ['US'],
#    'original_language': 'en',
#    'original_name': 'Hazbin Hotel',
#    'overview': "In attempt to find a non-violent alternative for reducing Hell's overpopulation, the daughter of Lucifer opens a rehabilitation hotel that offers a group of misfit demons a chance at redemption.",
#    'popularity': 168.639,
#    'poster_path': '/rXojaQcxVUubPLSrFV8PD4xdjrs.jpg',
#    'first_air_date': '2024-01-18',
#    'name': 'Hazbin Hotel',
#    'vote_average': 8.96,
#    'vote_count': 1005},
#   {'adult': False,
#    'backdrop_path': '/9faGSFi5jam6pDWGNd0p8JcJgXQ.jpg',
#    'genre_ids': [18, 80],
#    'id': 1396,
#    'origin_country': ['US'],
#    'original_language': 'en',
#    'original_name': 'Breaking Bad',
#    'overview': "Walter White, a New Mexico chemistry teacher, is diagnosed with Stage III cancer and given a prognosis of only two years left to live. He becomes filled with a sense of fearlessness and an unrelenting desire to secure his family's financial future at any cost as he enters the dangerous world of drugs and crime.",
#    'popularity': 843.249,
#    'poster_path': '/ztkUQFLlC19CCMYHW9o1zWhJRNq.jpg',
#    'first_air_date': '2008-01-20',
#    'name': 'Breaking Bad',
#    'vote_average': 8.913,
#    'vote_count': 13849},
#   {'adult': False,
#    'backdrop_path': '/rkB4LyZHo1NHXFEDHl9vSD9r1lI.jpg',
#    'genre_ids': [16, 18, 10765, 10759],
#    'id': 94605,
#    'origin_country': ['US'],
#    'original_language': 'en',
#    'original_name': 'Arcane',
#    'overview': 'Amid the stark discord of twin cities Piltover and Zaun, two sisters fight on rival sides of a war between magic technologies and clashing convictions.',
#    'popularity': 130.72,
#    'poster_path': '/fqldf2t8ztc9aiwn3k6mlX3tvRT.jpg',
#    'first_air_date': '2021-11-06',
#    'name': 'Arcane',
#    'vote_average': 8.745,
#    'vote_count': 3865},
#   {'adult': False,
#    'backdrop_path': '/kU98MbVVgi72wzceyrEbClZmMFe.jpg',
#    'genre_ids': [16, 10759, 10765],
#    'id': 246,
#    'origin_country': ['US'],
#    'original_language': 'en',
#    'original_name': 'Avatar: The Last Airbender',
#    'overview': 'In a war-torn world of elemental magic, a young boy reawakens to undertake a dangerous mystic quest to fulfill his destiny as the Avatar, and bring peace to the world.',
#    'popularity': 233.59,
#    'poster_path': '/v2vn1coUMPKw0GI1KGC5J4IXtqp.jpg',
#    'first_air_date': '2005-02-21',
#    'name': 'Avatar: The Last Airbender',
#    'vote_average': 8.733,
#    'vote_count': 4000},
#   {'adult': False,
#    'backdrop_path': '/2rmK7mnchw9Xr3XdiTFSxTTLXqv.jpg',
#    'genre_ids': [10759, 35, 16],
#    'id': 37854,
#    'origin_country': ['JP'],
#    'original_language': 'ja',
#    'original_name': 'ワンピース',
#    'overview': 'Years ago, the fearsome Pirate King, Gol D. Roger was executed leaving a huge pile of treasure and the famous "One Piece" behind. Whoever claims the "One Piece" will be named the new King of the Pirates.\n\nMonkey D. Luffy, a boy who consumed a "Devil Fruit," decides to follow in the footsteps of his idol, the pirate Shanks, and find the One Piece. It helps, of course, that his body has the properties of rubber and that he\'s surrounded by a bevy of skilled fighters and thieves to help him along the way.\n\nLuffy will do anything to get the One Piece and become King of the Pirates!',
#    'popularity': 185.797,
#    'poster_path': '/e3NBGiAifW9Xt8xD5tpARskjccO.jpg',
#    'first_air_date': '1999-10-20',
#    'name': 'One Piece',
#    'vote_average': 8.722,
#    'vote_count': 4524},
#   {'adult': False,
#    'backdrop_path': '/iDnTAeR2WNA62XQG0ivtteDSjd5.jpg',
#    'genre_ids': [16, 10759, 10765],
#    'id': 138502,
#    'origin_country': ['US'],
#    'original_language': 'en',
#    'original_name': "X-Men '97",
#    'overview': 'The X-Men, a band of mutants who use their uncanny gifts to protect a world that hates and fears them, are challenged like never before, forced to face a dangerous and unexpected new future.',
#    'popularity': 295.123,
#    'poster_path': '/9Ycz7yYRf9V4jk3YXwcZhFtbNcF.jpg',
#    'first_air_date': '2024-03-20',
#    'name': "X-Men '97",
#    'vote_average': 8.704,
#    'vote_count': 373},
#   {'adult': False,
#    'backdrop_path': '/A6tMQAo6t6eRFCPhsrShmxZLqFB.jpg',
#    'genre_ids': [10759, 16, 10765, 35, 18],
#    'id': 31911,
#    'origin_country': ['JP'],
#    'original_language': 'ja',
#    'original_name': '鋼の錬金術師 FULLMETAL ALCHEMIST',
#    'overview': 'Disregard for alchemy’s laws ripped half of Edward Elric’s limbs from his body and left his brother Alphonse’s soul clinging to a suit of armor. To restore what was lost, the brothers seek the Philosopher’s Stone. Enemies and allies – the corrupt military, the Homunculi, and foreign alchemists – will alter the Elric brothers course, but their purpose will remain unchanged and their bond unbreakable.',
#    'popularity': 421.078,
#    'poster_path': '/5ZFUEOULaVml7pQuXxhpR2SmVUw.jpg',
#    'first_air_date': '2009-04-05',
#    'name': 'Fullmetal Alchemist: Brotherhood',
#    'vote_average': 8.7,
#    'vote_count': 1970},
#   {'adult': False,
#    'backdrop_path': '/rBF8wVQN8hTWHspVZBlI3h7HZJ.jpg',
#    'genre_ids': [16, 35, 10765, 10759],
#    'id': 60625,
#    'origin_country': ['US'],
#    'original_language': 'en',
#    'original_name': 'Rick and Morty',
#    'overview': "Rick is a mentally-unbalanced but scientifically gifted old man who has recently reconnected with his family. He spends most of his time involving his young grandson Morty in dangerous, outlandish adventures throughout space and alternate universes. Compounded with Morty's already unstable family life, these events cause Morty much distress at home and school.",
#    'popularity': 653.989,
#    'poster_path': '/gdIrmf2DdY5mgN6ycVP0XlzKzbE.jpg',
#    'first_air_date': '2013-12-02',
#    'name': 'Rick and Morty',
#    'vote_average': 8.699,
#    'vote_count': 9526},
#   {'adult': False,
#    'backdrop_path': '/70YdbMELM4b8x8VXjlubymb2bQ0.jpg',
#    'genre_ids': [18, 10751],
#    'id': 70785,
#    'origin_country': ['CA'],
#    'original_language': 'en',
#    'original_name': 'Anne with an E',
#    'overview': 'A coming-of-age story about an outsider who, against all odds and numerous challenges, fights for love and acceptance and for her place in the world. The series centers on a young orphaned girl in the late 1890’s, who, after an abusive childhood spent in orphanages and the homes of strangers, is mistakenly sent to live with an elderly woman and her aging brother. Over time, 13-year-old Anne will transform their lives and eventually the small town in which they live with her unique spirit, fierce intellect and brilliant imagination.',
#    'popularity': 177.719,
#    'poster_path': '/6P6tXhjT5tK3qOXzxF9OMLlG7iz.jpg',
#    'first_air_date': '2017-03-19',
#    'name': 'Anne with an E',
#    'vote_average': 8.678,
#    'vote_count': 4594},
#   {'adult': False,
#    'backdrop_path': '/hPea3Qy5Gd6z4kJLUruBbwAH8Rm.jpg',
#    'genre_ids': [80, 18],
#    'id': 60059,
#    'origin_country': ['US'],
#    'original_language': 'en',
#    'original_name': 'Better Call Saul',
#    'overview': 'Six years before Saul Goodman meets Walter White. We meet him when the man who will become Saul Goodman is known as Jimmy McGill, a small-time lawyer searching for his destiny, and, more immediately, hustling to make ends meet. Working alongside, and, often, against Jimmy, is “fixer” Mike Ehrmantraut. The series tracks Jimmy’s transformation into Saul Goodman, the man who puts “criminal” in “criminal lawyer".',
#    'popularity': 533.887,
#    'poster_path': '/fC2HDm5t0kHl7mTm7jxMR31b7by.jpg',
#    'first_air_date': '2015-02-08',
#    'name': 'Better Call Saul',
#    'vote_average': 8.677,
#    'vote_count': 4975},
#   {'adult': False,
#    'backdrop_path': '/7BoRhg8zXP0ca9Zql4p8llCFR2P.jpg',
#    'genre_ids': [18, 10765, 35],
#    'id': 221851,
#    'origin_country': ['KR'],
#    'original_language': 'ko',
#    'original_name': '내 남편과 결혼해줘',
#    'overview': 'Kang Ji-won, a terminally ill cancer patient, is killed by her husband and best friend after she witnesses them having an affair. She wakes up 10 years before the incident and decides to seek revenge with the help of Yu Ji-hyuk, a director at the company where she works. Now, she must reclaim her fate and eliminate the trash from her life.',
#    'popularity': 162.314,
#    'poster_path': '/JV3DXl1fITfoyHtyPzNuZyzh8q.jpg',
#    'first_air_date': '2024-01-01',
#    'name': 'Marry My Husband',
#    'vote_average': 8.7,
#    'vote_count': 336},
#   {'adult': False,
#    'backdrop_path': '/900tHlUYUkp7Ol04XFSoAaEIXcT.jpg',
#    'genre_ids': [18],
#    'id': 87108,
#    'origin_country': ['US'],
#    'original_language': 'en',
#    'original_name': 'Chernobyl',
#    'overview': 'The true story of one of the worst man-made catastrophes in history: the catastrophic nuclear accident at Chernobyl. A tale of the brave men and women who sacrificed to save Europe from unimaginable disaster.',
#    'popularity': 104.168,
#    'poster_path': '/hlLXt2tOPT6RRnjiUmoxyG1LTFi.jpg',
#    'first_air_date': '2019-05-06',
#    'name': 'Chernobyl',
#    'vote_average': 8.673,
#    'vote_count': 6072},
#   {'adult': False,
#    'backdrop_path': '/3GQKYh6Trm8pxd2AypovoYQf4Ay.jpg',
#    'genre_ids': [16, 10759, 10765],
#    'id': 85937,
#    'origin_country': ['JP'],
#    'original_language': 'ja',
#    'original_name': '鬼滅の刃',
#    'overview': 'It is the Taisho Period in Japan. Tanjiro, a kindhearted boy who sells charcoal for a living, finds his family slaughtered by a demon. To make matters worse, his younger sister Nezuko, the sole survivor, has been transformed into a demon herself. Though devastated by this grim reality, Tanjiro resolves to become a “demon slayer” so that he can turn his sister back into a human, and kill the demon that massacred his family.',
#    'popularity': 237.548,
#    'poster_path': '/xUfRZu2mi8jH6SzQEJGP6tjBuYj.jpg',
#    'first_air_date': '2019-04-06',
#    'name': 'Demon Slayer: Kimetsu no Yaiba',
#    'vote_average': 8.67,
#    'vote_count': 6229},
#   {'adult': False,
#    'backdrop_path': '/cHyY5z4txdVyGtYMvBJhCqCcJso.jpg',
#    'genre_ids': [16, 10765, 18, 10759, 35],
#    'id': 92685,
#    'origin_country': ['US'],
#    'original_language': 'en',
#    'original_name': 'The Owl House',
#    'overview': "An animated fantasy-comedy series that follows Luz, a self-assured teenage girl who accidentally stumbles upon a portal to a magical world where she befriends a rebellious witch, Eda, and an adorably tiny warrior, King. Despite not having magical abilities, Luz pursues her dream of becoming a witch by serving as Eda's apprentice at the Owl House and ultimately finds a new family in an unlikely setting.",
#    'popularity': 207.094,
#    'poster_path': '/zhdy3PcNVE15wj1wrxn45ARZBnx.jpg',
#    'first_air_date': '2020-01-10',
#    'name': 'The Owl House',
#    'vote_average': 8.667,
#    'vote_count': 1540},
#   {'adult': False,
#    'backdrop_path': '/3MC8VIxq8u1vKOKTfz6FtrFXuMZ.jpg',
#    'genre_ids': [10765, 18, 10759, 9648],
#    'id': 135157,
#    'origin_country': ['KR'],
#    'original_language': 'ko',
#    'original_name': '환혼',
#    'overview': "A powerful sorceress in a blind woman's body encounters a man from a prestigious family, who wants her help to change his destiny.",
#    'popularity': 169.388,
#    'poster_path': '/q2IiPRSXPOZ6qVRj36WRAYEQyHs.jpg',
#    'first_air_date': '2022-06-18',
#    'name': 'Alchemy of Souls',
#    'vote_average': 8.663,
#    'vote_count': 528},
#   {'adult': False,
#    'backdrop_path': '/rqbCbjB19amtOtFQbb3K2lgm2zv.jpg',
#    'genre_ids': [16, 10765, 10759],
#    'id': 1429,
#    'origin_country': ['JP'],
#    'original_language': 'ja',
#    'original_name': '進撃の巨人',
#    'overview': 'Several hundred years ago, humans were nearly exterminated by Titans. Titans are typically several stories tall, seem to have no intelligence, devour human beings and, worst of all, seem to do it for the pleasure rather than as a food source. A small percentage of humanity survived by walling themselves in a city protected by extremely high walls, even taller than the biggest Titans. Flash forward to the present and the city has not seen a Titan in over 100 years. Teenage boy Eren and his foster sister Mikasa witness something horrific as the city walls are destroyed by a Colossal Titan that appears out of thin air. As the smaller Titans flood the city, the two kids watch in horror as their mother is eaten alive. Eren vows that he will murder every single Titan and take revenge for all of mankind.',
#    'popularity': 229.193,
#    'poster_path': '/hTP1DtLGFamjfu8WqjnuQdP1n4i.jpg',
#    'first_air_date': '2013-04-07',
#    'name': 'Attack on Titan',
#    'vote_average': 8.661,
#    'vote_count': 6174},
#   {'adult': False,
#    'backdrop_path': '/2w8FaLwwJTWr6ExUMeVgT2Th5YT.jpg',
#    'genre_ids': [16, 35, 18, 10759],
#    'id': 42705,
#    'origin_country': ['JP'],
#    'original_language': 'ja',
#    'original_name': 'はじめの一歩',
#    'overview': "Makunouchi Ippo is an ordinary high school student in Japan. Since he spends most of his time away from school helping his mother run the family business, he doesn't get to enjoy his younger years like most teenagers. Always a target for bullying at school (the family fishing business grants him a distinct odor), Ippo's life is one of hardship. One of these after-school bullying sessions turns Ippo's life around for the better, as he is saved by a boxer named Takamura. He decides to follow in Takamura's footsteps and train to become a boxer, giving his life direction and purpose. Ippo's path to perfecting his pugilistic prowess is just beginning...",
#    'popularity': 368.83,
#    'poster_path': '/i3U3J2MWovIBZBnZYYiOLBXqNJZ.jpg',
#    'first_air_date': '2000-10-03',
#    'name': 'Fighting Spirit',
#    'vote_average': 8.66,
#    'vote_count': 1009},
#   {'adult': False,
#    'backdrop_path': '/dfmPbyeZZSz3bekeESvMJaH91gS.jpg',
#    'genre_ids': [16, 10765, 10759, 18],
#    'id': 95557,
#    'origin_country': ['US'],
#    'original_language': 'en',
#    'original_name': 'INVINCIBLE',
#    'overview': 'Mark Grayson is a normal teenager except for the fact that his father is the most powerful superhero on the planet. Shortly after his seventeenth birthday, Mark begins to develop powers of his own and enters into his father’s tutelage.',
#    'popularity': 219.155,
#    'poster_path': '/dMOpdkrDC5dQxqNydgKxXjBKyAc.jpg',
#    'first_air_date': '2021-03-25',
#    'name': 'INVINCIBLE',
#    'vote_average': 8.652,
#    'vote_count': 4337},
#   {'adult': False,
#    'backdrop_path': '/3ILMlmC30QUnYkY3XEBOyJ82Dqu.jpg',
#    'genre_ids': [10759, 16, 10765],
#    'id': 65930,
#    'origin_country': ['JP'],
#    'original_language': 'ja',
#    'original_name': '僕のヒーローアカデミア',
#    'overview': 'A superhero-admiring boy without any powers enrolls in a prestigious hero academy and learns what it really means to be a hero.',
#    'popularity': 202.576,
#    'poster_path': '/phuYuzqWW9ru8EA3HVjE9W2Rr3M.jpg',
#    'first_air_date': '2016-04-03',
#    'name': 'My Hero Academia',
#    'vote_average': 8.65,
#    'vote_count': 4779}],
#  'total_pages': 101,
#  'total_results': 2004}

# %%
pd.DataFrame(response.json()['results'])
# Out:
#     adult                     backdrop_path                   genre_ids  \
# 0   False  /96RT2A47UdzWlUfvIERFyBsLhL2.jpg      [16, 18, 10759, 10765]
# 1   False  /9kyyQXy79YRdY5mhrYKyktbFMev.jpg             [16, 35, 10765]
# 2   False  /9faGSFi5jam6pDWGNd0p8JcJgXQ.jpg                    [18, 80]
# 3   False  /rkB4LyZHo1NHXFEDHl9vSD9r1lI.jpg      [16, 18, 10765, 10759]
# 4   False  /kU98MbVVgi72wzceyrEbClZmMFe.jpg          [16, 10759, 10765]
# 5   False  /2rmK7mnchw9Xr3XdiTFSxTTLXqv.jpg             [10759, 35, 16]
# 6   False  /iDnTAeR2WNA62XQG0ivtteDSjd5.jpg          [16, 10759, 10765]
# 7   False  /A6tMQAo6t6eRFCPhsrShmxZLqFB.jpg  [10759, 16, 10765, 35, 18]
# 8   False   /rBF8wVQN8hTWHspVZBlI3h7HZJ.jpg      [16, 35, 10765, 10759]
# 9   False  /70YdbMELM4b8x8VXjlubymb2bQ0.jpg                 [18, 10751]
# 10  False  /hPea3Qy5Gd6z4kJLUruBbwAH8Rm.jpg                    [80, 18]
# 11  False  /7BoRhg8zXP0ca9Zql4p8llCFR2P.jpg             [18, 10765, 35]
# 12  False  /900tHlUYUkp7Ol04XFSoAaEIXcT.jpg                        [18]
# 13  False  /3GQKYh6Trm8pxd2AypovoYQf4Ay.jpg          [16, 10759, 10765]
# 14  False  /cHyY5z4txdVyGtYMvBJhCqCcJso.jpg  [16, 10765, 18, 10759, 35]
# 15  False  /3MC8VIxq8u1vKOKTfz6FtrFXuMZ.jpg    [10765, 18, 10759, 9648]
# 16  False  /rqbCbjB19amtOtFQbb3K2lgm2zv.jpg          [16, 10765, 10759]
# 17  False  /2w8FaLwwJTWr6ExUMeVgT2Th5YT.jpg         [16, 35, 18, 10759]
# 18  False  /dfmPbyeZZSz3bekeESvMJaH91gS.jpg      [16, 10765, 10759, 18]
# 19  False  /3ILMlmC30QUnYkY3XEBOyJ82Dqu.jpg          [10759, 16, 10765]
#
#         id origin_country original_language               original_name  \
# 0   209867           [JP]                ja                    葬送のフリーレン
# 1    94954           [US]                en                Hazbin Hotel
# 2     1396           [US]                en                Breaking Bad
# 3    94605           [US]                en                      Arcane
# 4      246           [US]                en  Avatar: The Last Airbender
# 5    37854           [JP]                ja                       ワンピース
# 6   138502           [US]                en                   X-Men '97
# 7    31911           [JP]                ja  鋼の錬金術師 FULLMETAL ALCHEMIST
# 8    60625           [US]                en              Rick and Morty
# 9    70785           [CA]                en              Anne with an E
# 10   60059           [US]                en            Better Call Saul
# 11  221851           [KR]                ko                  내 남편과 결혼해줘
# 12   87108           [US]                en                   Chernobyl
# 13   85937           [JP]                ja                        鬼滅の刃
# 14   92685           [US]                en               The Owl House
# 15  135157           [KR]                ko                          환혼
# 16    1429           [JP]                ja                       進撃の巨人
# 17   42705           [JP]                ja                      はじめの一歩
# 18   95557           [US]                en                  INVINCIBLE
# 19   65930           [JP]                ja                 僕のヒーローアカデミア
#
#                                              overview  popularity  \
# 0   After the party of heroes defeated the Demon K...     449.620
# 1   In attempt to find a non-violent alternative f...     168.639
# 2   Walter White, a New Mexico chemistry teacher, ...     843.249
# 3   Amid the stark discord of twin cities Piltover...     130.720
# 4   In a war-torn world of elemental magic, a youn...     233.590
# 5   Years ago, the fearsome Pirate King, Gol D. Ro...     185.797
# 6   The X-Men, a band of mutants who use their unc...     295.123
# 7   Disregard for alchemy’s laws ripped half of Ed...     421.078
# 8   Rick is a mentally-unbalanced but scientifical...     653.989
# 9   A coming-of-age story about an outsider who, a...     177.719
# 10  Six years before Saul Goodman meets Walter Whi...     533.887
# 11  Kang Ji-won, a terminally ill cancer patient, ...     162.314
# 12  The true story of one of the worst man-made ca...     104.168
# 13  It is the Taisho Period in Japan. Tanjiro, a k...     237.548
# 14  An animated fantasy-comedy series that follows...     207.094
# 15  A powerful sorceress in a blind woman's body e...     169.388
# 16  Several hundred years ago, humans were nearly ...     229.193
# 17  Makunouchi Ippo is an ordinary high school stu...     368.830
# 18  Mark Grayson is a normal teenager except for t...     219.155
# 19  A superhero-admiring boy without any powers en...     202.576
#
#                          poster_path first_air_date  \
# 0   /dqZENchTd7lp5zht7BdlqM7RBhD.jpg     2023-09-29
# 1   /rXojaQcxVUubPLSrFV8PD4xdjrs.jpg     2024-01-18
# 2   /ztkUQFLlC19CCMYHW9o1zWhJRNq.jpg     2008-01-20
# 3   /fqldf2t8ztc9aiwn3k6mlX3tvRT.jpg     2021-11-06
# 4   /v2vn1coUMPKw0GI1KGC5J4IXtqp.jpg     2005-02-21
# 5   /e3NBGiAifW9Xt8xD5tpARskjccO.jpg     1999-10-20
# 6   /9Ycz7yYRf9V4jk3YXwcZhFtbNcF.jpg     2024-03-20
# 7   /5ZFUEOULaVml7pQuXxhpR2SmVUw.jpg     2009-04-05
# 8   /gdIrmf2DdY5mgN6ycVP0XlzKzbE.jpg     2013-12-02
# 9   /6P6tXhjT5tK3qOXzxF9OMLlG7iz.jpg     2017-03-19
# 10  /fC2HDm5t0kHl7mTm7jxMR31b7by.jpg     2015-02-08
# 11   /JV3DXl1fITfoyHtyPzNuZyzh8q.jpg     2024-01-01
# 12  /hlLXt2tOPT6RRnjiUmoxyG1LTFi.jpg     2019-05-06
# 13  /xUfRZu2mi8jH6SzQEJGP6tjBuYj.jpg     2019-04-06
# 14  /zhdy3PcNVE15wj1wrxn45ARZBnx.jpg     2020-01-10
# 15  /q2IiPRSXPOZ6qVRj36WRAYEQyHs.jpg     2022-06-18
# 16  /hTP1DtLGFamjfu8WqjnuQdP1n4i.jpg     2013-04-07
# 17  /i3U3J2MWovIBZBnZYYiOLBXqNJZ.jpg     2000-10-03
# 18  /dMOpdkrDC5dQxqNydgKxXjBKyAc.jpg     2021-03-25
# 19  /phuYuzqWW9ru8EA3HVjE9W2Rr3M.jpg     2016-04-03
#
#                                 name  vote_average  vote_count
# 0      Frieren: Beyond Journey's End         8.965         229
# 1                       Hazbin Hotel         8.960        1005
# 2                       Breaking Bad         8.913       13849
# 3                             Arcane         8.745        3865
# 4         Avatar: The Last Airbender         8.733        4000
# 5                          One Piece         8.722        4524
# 6                          X-Men '97         8.704         373
# 7   Fullmetal Alchemist: Brotherhood         8.700        1970
# 8                     Rick and Morty         8.699        9526
# 9                     Anne with an E         8.678        4594
# 10                  Better Call Saul         8.677        4975
# 11                  Marry My Husband         8.700         336
# 12                         Chernobyl         8.673        6072
# 13    Demon Slayer: Kimetsu no Yaiba         8.670        6229
# 14                     The Owl House         8.667        1540
# 15                  Alchemy of Souls         8.663         528
# 16                   Attack on Titan         8.661        6174
# 17                   Fighting Spirit         8.660        1009
# 18                        INVINCIBLE         8.652        4337
# 19                  My Hero Academia         8.650        4779
